# %%
import matplotlib.pyplot as plt
plt.rc('font', size=18)
import pandas as pd
import seaborn as sns
import warnings 

from MetricCalculation import Coverage as cov
from MetricCalculation import RuleQuality as RQ

warnings.filterwarnings('ignore')
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Nonprivate

# %%
base = pd.read_csv("../Results/Nonprivate/CoverageSummaryDF.csv")

# %% [markdown]
# ## Rule Coverage

# %%
def plotCoverageQuery(queries, dataList, labelList, filename, ylabel="Percent of Client Rules Found"):
    plt.figure(figsize=(12, 7))
    plt.rc('font', size=18)
    
    for i in range(len(dataList)):
        plt.plot(queries, dataList[i], label=labelList[i])

    plt.xlabel("Number of Queries")
    plt.ylabel(ylabel)
    plt.legend()


    plt.tight_layout()
    plt.savefig(filename)

# %%
queries = base["Queries"]
dataList = [base["ICU Percent Found Rules B"], base["ICU Percent Found Rules C"], base['ICU Percent Found Rules Eps 1000']]
labelList = ['Nonprivate Baseline', 'Nonprivate TED', 'Private, eps=1000']
plotCoverageQuery(queries, dataList, labelList, filename="ICU_Rule_Coverage.png")

# %%
queries = base["Queries"]
dataList = [base["Sepsis Percent Found Rules B"], base["Sepsis Percent Found Rules C"], base['Sepsis Percent Found Rules Eps 1000']]
labelList = ['Nonprivate Baseline', 'Nonprivate TED', 'Private, eps=1000']
plotCoverageQuery(queries, dataList, labelList, filename="Sepsis_Rule_Coverage.png")

# %%
queries = base["Queries"]
dataList = [base["T1D Percent Found Rules B"], base["T1D Percent Found Rules C"], base['T1D Percent Found Rules Eps 1000']]
labelList = ['Nonprivate Baseline', 'Nonprivate TED', 'Private, eps=1000']
plotCoverageQuery(queries, dataList, labelList, filename="T1D_Rule_Coverage.png")

# %% [markdown]
# ## Structure coverage

# %%
#Plot Structures
queries = base["Queries"]
dataList = [base["ICU Percent Found Structs B"], base["ICU Percent Found Structs C"]]
labelList = ['Nonprivate Baseline', 'Nonprivate TED']
plotCoverageQuery(queries, dataList, labelList, filename="ICU_Structure_Coverage.png", ylabel='Percent of Client Structures Found')

# %%
queries = base["Queries"]
dataList = [base["Sepsis Percent Found Structs B"], base["Sepsis Percent Found Structs C"]]
labelList = ['Nonprivate Baseline', 'Nonprivate TED']
plotCoverageQuery(queries, dataList, labelList, filename="Sepsis_Structure_Coverage.png", ylabel='Percent of Client Structures Found')

# %%
queries = base["Queries"]
dataList = [base["T1D Percent Found Structs B"], base["T1D Percent Found Structs C"]]
labelList = ['Nonprivate Baseline', 'Nonprivate TED']
plotCoverageQuery(queries, dataList, labelList, filename="T1D_Structure_Coverage.png", ylabel='Percent of Client Structures Found')

# %% [markdown]
# # Private Coverage

# %%
def summaryPrivRules(df, save):
    cps = sorted(list(set(df['Cp'])))
    lambdas = sorted(list(set(df['Lambda'])))
    epsilons = sorted(list(set(df['Epsilon'])), reverse=True)

    maxFR = max(df['Found Rules'])
    maxNR = max(df['Non Rules'])
    maxRules = maxFR + maxNR

    fig, axes = plt.subplots(figsize=(20, 20), nrows=len(cps), ncols=len(lambdas))
    row = 0
    col = 0
    for c in cps:
        col = 0
        for l in lambdas:
            cpdf = df.loc[df['Cp'] == c]
            subset = cpdf.loc[df['Lambda'] == l][['Found Rules', 'Non Rules']]
            FRErr = cpdf.loc[df['Lambda'] == l]['Found Rules Std']
            NRErr = cpdf.loc[df['Lambda'] == l]['Non Rules Std']

            ax = subset.plot(kind="bar", stacked=True, yerr=[FRErr, NRErr], ax=axes[row, col])

            ax.set_ylabel("Total Rules")
            ax.legend(['Found Rules', 'Non Rules'], loc='upper right')

            ax.set_title("Cp: " + str(c) + "; Lambda: " + str(l))
            ax.set_xlabel("Epsilon")
            ax.set_ylim(0, maxRules)

            ax.set_xticklabels(labels=epsilons, rotation=0, minor=False)
            handles, labels = ax.get_legend_handles_labels()
            col += 1
        row += 1
    fig.tight_layout()
    save = save.replace(".", "-")
    fig.savefig(save + "Summary_Rules_Nonrules")
    fig.show()
    
plt.rc('font', size=14)

# %%
df = pd.read_csv('../Results/ICU_AveragedCoverageSummaryDF.csv')

summaryPrivRules(df, save="ICU_")

# %%
df = pd.read_csv('../Results/Sepsis_AveragedCoverageSummaryDF.csv')

summaryPrivRules(df, save="Sepsis_")

# %%
df = pd.read_csv('../Results/T1D_AveragedCoverageSummaryDF.csv')

summaryPrivRules(df, save="T1D_")

# %% [markdown]
# # Rule Quality
